# %% [markdown]
# # Test code

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()

# db_url=dialect+driver://dbuser;dbpass;dbhost;dbport;dbname
db_url = f'mysql+pymysql://{os.getenv("dbuser")}:{os.getenv("dbpass")}@{os.getenv("dbhost")}:{os.getenv("dbport")}/{os.getenv("dbname")}'

engine=create_engine(db_url)
session=sessionmaker(bind=engine)
db=session()

# creating table to our database

# query=text("SELECT * FROM user")
# db_users= db.execute(query).fetchall()
# user_df= pd.DataFrame(db_users)
# user_df
# Out:
#     id               name                        email     password
# 0    1     Saheed Olayemi                ola@gmail.com       Ola123
# 1    2   Olayemi Olayinka               yemi@gmail.com      yemi123
# 2    3     Saheed Olayemi                ola@gmail.com       Ola123
# 3    4   Olayemi Olayinka               yemi@gmail.com      yemi123
# 4    5    Michael Adeyemi    michael.adeyemi@gmail.com      mike123
# 5    6        Aisha Bello        aisha.bello@gmail.com     aisha123
# 6    7       Tunde Bakare       tunde.bakare@gmail.com     tunde123
# 7    8     Chinedu Okafor     chinedu.okafor@gmail.com   chinedu123
# 8    9        Ngozi Nwosu        ngozi.nwosu@gmail.com     ngozi123
# 9   10       Ibrahim Musa       ibrahim.musa@gmail.com   ibrahim123
# 10  11       Fatima Sanni       fatima.sanni@gmail.com    fatima123
# 11  12      Kunle Adebayo      kunle.adebayo@gmail.com     kunle123
# 12  13      Grace Johnson      grace.johnson@gmail.com     grace123
# 13  14      Samuel Peters      samuel.peters@gmail.com    samuel123
# 14  15           Joy Uche           joy.uche@gmail.com       joy123
# 15  16       Emeka Nnamdi       emeka.nnamdi@gmail.com     emeka123
# 16  17     Hauwa Suleiman     hauwa.suleiman@gmail.com     hauwa123
# 17  18         David Mark         david.mark@gmail.com     david123
# 18  19       Blessing Eze       blessing.eze@gmail.com  blessing123
# 19  20   Oluwaseun Adeola        seun.adeola@gmail.com      seun123
# 20  21          Chika Obi          chika.obi@gmail.com     chika123
# 21  22   Maryam Abdullahi   maryam.abdullahi@gmail.com    maryam123
# 22  23          John Paul          john.paul@gmail.com      john123
# 23  24       Esther James       esther.james@gmail.com    esther123
# 24  25        Collins Udo        collins.udo@gmail.com   collins123
# 25  26       Ruth Akinola       ruth.akinola@gmail.com      ruth123
# 26  27        Bola Shittu        bola.shittu@gmail.com      bola123
# 27  28       Chisom Nweke       chisom.nweke@gmail.com    chisom123
# 28  29      Ifeanyi Okeke      ifeanyi.okeke@gmail.com   ifeanyi123
# 29  30    Patience Yakubu    patience.yakubu@gmail.com  patience123
# 30  31      Opeyemi Lawal      opeyemi.lawal@gmail.com   opeyemi123
# 31  32         Kemi Alabi         kemi.alabi@gmail.com      kemi123
# 32  33       Gbenga Ajayi       gbenga.ajayi@gmail.com    gbenga123
# 33  34          Amaka Eze          amaka.eze@gmail.com     amaka123
# 34  35   Suleiman Danjuma   suleiman.danjuma@gmail.com  suleiman123
# 35  36  Victoria Adebanjo  victoria.adebanjo@gmail.com  victoria123
# 36  37         Henry Okon         henry.okon@gmail.com     henry123
# 37  38    Olamide Afolabi    olamide.afolabi@gmail.com   olamide123
# 38  39      Chinyere Umeh      chinyere.umeh@gmail.com  chinyere123
# 39  40  Ishaq Abdulkareem  ishaq.abdulkareem@gmail.com     ishaq123
# 40  41          Janet Ojo          janet.ojo@gmail.com     janet123
# 41  42   Raphael Adekunle   raphael.adekunle@gmail.com   raphael123
# 42  43    Hadiza Mohammed    hadiza.mohammed@gmail.com    hadiza123
# 43  44       Peter Obioma       peter.obioma@gmail.com     peter123
# 44  45        Sarah Yusuf        sarah.yusuf@gmail.com     sarah123
# 45  46      Daniel Okonjo      daniel.okonjo@gmail.com    daniel123
# 46  47      Mariam Tijani      mariam.tijani@gmail.com    mariam123
# 47  48      Felix Omotayo      felix.omotayo@gmail.com     felix123
# 48  49   Gloria Nwachukwu   gloria.nwachukwu@gmail.com    gloria123
# 49  50        Ijeoma Anya        ijeoma.anya@gmail.com    ijeoma123
# 50  51     Mustapha Aliyu     mustapha.aliyu@gmail.com  mustapha123
# 51  52   Precious Adeyeye   precious.adeyeye@gmail.com  precious123
